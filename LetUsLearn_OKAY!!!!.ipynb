# %% [markdown]
# <a href="https://colab.research.google.com/github/kingdewunmi/DataScience/blob/main/LetUsLearn_OKAY!!!!.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Practise
# This is to help every one of us master the skills we learnt yesterday and also to push us to make more effort to be better

# %% [markdown]
# ## Overview
# The dataset that we are expected to use for this practise session is the same 'autos.csv' dataset that was used at our last meeting...
#
# So let's get at it!

# %%
# 1 
# Rename this notebook to your name and surname

# %%
# 2
# import the necessary packages (pandas, matplotlib and seaborn) and import the autos dataset please call the dataset df


# df=pd.read_csv('autos.csv') # this can change depending on the location of 'autos.csv'

# %%
# 3
#write a code to visualize the top 5 rows of the dataset
# Out:
#    symboling  normalized-losses  make-id fuel-type aspiration num-of-doors  \
# 0          3                NaN        1       gas        std          two
# 1          3                NaN        1       gas        std          two
# 2          1                NaN        1       gas        std          two
# 3          2              164.0        2       gas        std         four
# 4          2              164.0        2       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
#4 fun
# Check how many unique entries are in the folloewing columns [fuel-type, aspiration, num-of-doors, body-style, drive-wheels, engine-location]
# You can call the .unique() function on the columns
# Out:
# Number of Unique entry in fuel-type is 2
# Number of Unique entry in aspiration is 2
# Number of Unique entry in num-of-doors is 2
# Number of Unique entry in body-style is 5
# Number of Unique entry in drive-wheels is 3
# Number of Unique entry in engine-location is 2

# %%
# 5
# Convert [fuel-type, aspiration, num-of-doors, body-style, drive-wheels, engine-location] to categorical using the .astype() method
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216 entries, 0 to 215
# Data columns (total 26 columns):
# symboling            216 non-null int64
# normalized-losses    175 non-null float64
# make-id              216 non-null int64
# fuel-type            216 non-null category
# aspiration           216 non-null category
# num-of-doors         214 non-null category
# body-style           216 non-null category
# drive-wheels         216 non-null category
# engine-location      216 non-null category
# wheel-base           216 non-null float64
# length               216 non-null float64
# width                216 non-null float64
# height               216 non-null float64
# curb-weight          216 non-null int64
# engine-type          216 non-null object
# num-of-cylinders     216 non-null object
# engine-size          216 non-null int64
# fuel-system          216 non-null object
# bore                 212 non-null float64
# stroke               212 non-null float64
# ...

# %%
# 6
# lets visualize the correlation between each column as percentages using the heatmap method and also annotating the plot

# %%
# 7
# Lets draw a bar chart on the following columns to see their distribution [fuel-type, aspiration, num-of-doors, body-style, drive-wheels, engine-location]
# create a function to draw it all once

# %%
# 8 
# Make 2 plots one a scatter plot without the regression line and the second with the regression line
# plt.scatter(df['length'], df['price'],  s=df['horsepower'], cmap='g')

# %%
# 9 
# Make a scatter plot and colour each point differently based on the categories they belong to in fuel-type column

# %%
# 10 
# Find out the mean and median of all the numerical columns

# the out put should look like
# The mean value of column -------- is -----------
# the mean value of column -------- is -----------
# Out:
# The mean value of column "symboling" is 0.7268518518518519
# The mean value of column "make-id" is 13.643518518518519
# The mean value of column "curb-weight" is 2580.1296296296296
# The mean value of column "engine-size" is 127.68981481481481
# The mean value of column "city-mpg" is 25.01388888888889
# The mean value of column "highway-mpg" is 30.5
# The mean value of column "normalized-losses" is 120.08
# The mean value of column "wheel-base" is 99.15
# The mean value of column "length" is 174.800462962963
# The mean value of column "width" is 66.01249999999999
# The mean value of column "height" is 53.85277777777778
# The mean value of column "bore" is 3.3470283018867923
# The mean value of column "stroke" is 3.2498113207547172
# The mean value of column "compression-ratio" is 10.146851851851853
# The mean value of column "horsepower" is 105.4766355140187
# The mean value of column "peak-rpm" is 5133.878504672897
# The mean value of column "price" is 13459.094339622641
# ...

# %%
# create a list to contain all the numbers like int and float all numeric columns
# Out:
# the mean of "symboling" is 0.7268518518518519
# the median of "symboling" is 1.0
# the least value of "symboling" is -2
# the max or Biggest of "symboling" is 3
# ---------------------------------------------------
# the mean of "normalized-losses" is 120.08
# the median of "normalized-losses" is 110.0
# the least value of "normalized-losses" is 65.0
# the max or Biggest of "normalized-losses" is 256.0
# ---------------------------------------------------
# the mean of "make-id" is 13.643518518518519
# the median of "make-id" is 14.0
# the least value of "make-id" is 1
# the max or Biggest of "make-id" is 22
# ---------------------------------------------------
# the mean of "wheel-base" is 99.15
# the median of "wheel-base" is 97.2
# the least value of "wheel-base" is 86.6
# the max or Biggest of "wheel-base" is 120.9
# ---------------------------------------------------
# the mean of "length" is 174.800462962963
# the median of "length" is 173.45
# ...

# %%
# based on num of doors which category of cars is more expensive and by how much

# %%
# which category of cars has the highest horsepower, compression_ratio and peak_rpm

# %%
# how many cars according to categories uses the fuel type of gas

# %% [markdown]
# # Submission
#
# i HOPE WE LEARNT SOMETHING LET ME KNOW WHAT UP IF THERE IS ANYTHING DIFFERENT FROM SKY YOU KNOW WHAT I MEAN
# LOL
#
# ### Thank you and have fun visualizing
